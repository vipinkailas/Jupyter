# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
conn=sqlite3.connect("Factbook.db")
cursor = conn.cursor()
q1="select * from sqlite_master where type='table';"
pd.read_sql_query(q1,conn)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

conn = sqlite3.connect("factbook.db")
q2= "select population, population_growth,birth_rate,death_rate from facts where population!=(select min(population) from facts) and population != (select max(population) from facts)"
pd.read_sql_query(q2,conn).hist(ax=ax)
# Out:
# /anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2882: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10fbcc590>,
# ...
#       dtype=object)
